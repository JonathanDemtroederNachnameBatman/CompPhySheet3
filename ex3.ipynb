# %%
import network
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Aufgabe 3

# %%
m = 5
hidden_layer_size = 6

def xor(y1, y2):
    return 1.0 * ((y1 * y2) < 0)

layer_Sizes = [2]
for i in range(m):
    layer_Sizes.append(hidden_layer_size)
layer_Sizes.append(1)    
XOR_Network = network.Network(layer_sizes=layer_Sizes,
                              activation_function_id='relu',
                              cost_function_id='square',
                              batch_size=500,
                              eta=.01,
                              target_function=xor)

# %% [markdown]
# > Trainiere Netzwerk mit 5 hidden layers:

# %%
xrange=np.linspace(-0.5,0.5,40)
X0,X1=np.meshgrid(xrange,xrange)

test_batchsize=np.shape(X0)[0]*np.shape(X0)[1]
testsample=np.zeros([test_batchsize,2])
testsample[:,0]=X0.flatten()
testsample[:,1]=X1.flatten()

XOR_Network.train_network(40000)
res, _, _ = XOR_Network.apply_net(testsample) 

plt.imshow(np.reshape(res, np.shape(X0)),
           interpolation='nearest', origin='lower',
           extent=(xrange[0],xrange[-1],xrange[0],xrange[-1]))
plt.colorbar()
plt.show()

# %% [markdown]
# > 4 hidden layers:

# %%
XOR_Network.remove_last_hidden_layer()

res, _, _ = XOR_Network.apply_net(testsample) 

plt.imshow(np.reshape(res, np.shape(X0)),
           interpolation='nearest', origin='lower',
           extent=(xrange[0],xrange[-1],xrange[0],xrange[-1]))
plt.colorbar()
plt.show()

# %% [markdown]
# > 3 hidden layers:

# %%
XOR_Network.remove_last_hidden_layer()

res, _, _ = XOR_Network.apply_net(testsample) 

plt.imshow(np.reshape(res, np.shape(X0)),
           interpolation='nearest', origin='lower',
           extent=(xrange[0],xrange[-1],xrange[0],xrange[-1]))
plt.colorbar()
plt.show()

# %% [markdown]
# > 2 hidden layers:

# %%
XOR_Network.remove_last_hidden_layer()

res, _, _ = XOR_Network.apply_net(testsample) 

plt.imshow(np.reshape(res, np.shape(X0)),
           interpolation='nearest', origin='lower',
           extent=(xrange[0],xrange[-1],xrange[0],xrange[-1]))
plt.colorbar()
plt.show()

# %% [markdown]
# > 1 hidden layer:

# %%
XOR_Network.remove_last_hidden_layer()

res, _, _ = XOR_Network.apply_net(testsample) 

plt.imshow(np.reshape(res, np.shape(X0)),
           interpolation='nearest', origin='lower',
           extent=(xrange[0],xrange[-1],xrange[0],xrange[-1]))
plt.colorbar()
plt.show()

# %% [markdown]
# > Ergebnis: Information ist in den ersten bis mittleren layers konzentriert
